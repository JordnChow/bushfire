# %%
from ultralytics import YOLO

# %%
model = YOLO('best.pt')

# %%
results = model('./8468567365_18760a6d8b_o.jpg')
# Out:
# image 1/1 C:\Users\jorda\Work\School\Software-Engineering\fire-detection\8468567365_18760a6d8b_o.jpg: 512x512 fire 0.99, nofire 0.01, 186.5ms
# Speed: 59.4ms preprocess, 186.5ms inference, 0.1ms postprocess per image at shape (1, 3, 512, 512)

# %%
model.predict(source="./videoplayback.mp4", save=True,show=False, conf=0.5)
print()
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1432) C:\Users\jorda\Work\School\Software-Engineering\fire-detection\videoplayback.mp4: 512x512 fire 1.00, nofire 0.00, 14.8ms
# video 1/1 (frame 2/1432) C:\Users\jorda\Work\School\Software-Engineering\fire-detection\videoplayback.mp4: 512x512 fire 1.00, nofire 0.00, 14.5ms
# ...
